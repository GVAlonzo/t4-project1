# %%
import pandas as pd

# %%
file1 = "data/Clark_County_Fire_Stations.csv"
file2 = "data/Fire_Department_Incident_Count_Summary.csv"
file3 = "data/Zoning.csv"

# %%
file1 = pd.read_csv(file1)
file2 = pd.read_csv(file2)
file3 = pd.read_csv(file3)

# %%
file1.head()
# Out:
#      FACILITY_NAME          FACILITY_ADDRESS CITY_CODE  STATION_NUMBER  \
# 0  STATION 1 - CLV  500 N CASINO CENTER BLVD       CLV               1
# 1   STATION 1 - BC               1101 ELM AV        BC               1
# 2  STATION 2 - CLV          900 S DURANGO DR       CLV               2
# 3  STATION 3 - CLV      2645 W WASHINGTON AV       CLV               3
# 4  STATION 4 - CLV             421 S 15TH ST       CLV               4
#
#       ENGINE     RESCUE  TRUCK  BATTALION CAPABILITI  \
# 0  1,201,301  1201301.0    1.0          1   ALS &ILS
# 1    121,122        NaN  121.0         12        NaN
# 2          2        2.0    NaN         10        ALS
# 3      3,203        3.0    3.0          1        ALS
# 4      4,204     4204.0    4.0          1  ALS & ILS
#
#                                           OTHER_UNIT CONSTRUCTION_YEAR  \
# 0  BAT1, Eng401&501,Res401,501,601,100,Sqaud1,ILS...         6/23/1984
# 1                                    SQUAD/AMBULANCE              1960
# ...

# %%
file2.head()
# Out:
#    ID     Category             Fiscal_Year  Count_  Per_Capita  ObjectId
# 0   1      Medical  2012/06/30 00:00:00+00   78038     5.86356         1
# 1   2         Fire  2012/06/30 00:00:00+00    3022     5.86356         2
# 2   3  Public Need  2012/06/30 00:00:00+00    4271     5.86356         3
# 3   4        Other  2012/06/30 00:00:00+00     913     5.86356         4
# 4   5      Medical  2013/06/30 00:00:00+00   81572     5.94294         5

# %%
file3.head()
# Out:
#         PARCEL     PARENTPCL   ZONE     EZFILE ROIZONE ROIZFILE   ORD  \
# 0  13809597012  0.000000e+00  R-PD5  Z-0102-01                   5622
# 1  12507716003  0.000000e+00    C-1   ZON-7290                   5937
# 2  13816297009  1.381630e+10  R-PD5  Z-0043-87
# 3  16204512019  1.620451e+10    R-1
# 4  12512597021  0.000000e+00  R-PD7  Z-0059-01                   5761
#
#   EXP_DATE  SHADE      HZFILE_1  ... USE_10 MULTI_ZONE UDC_ZONE UDC_DATE  \
# 0              87  Z-0102-01(1)  ...                 0
# 1             111     A-0003-64  ...                 0
# 2              87  A-0020-86(A)  ...                 0
# 3              83                ...                 0
# 4              87     A-0003-64  ...                 0
#
#                                          DESCRIPTION LABEL_CLASS ORIG_FID  \
# 0  Residential Planned Development - 5 Unit Per Acre         721      675
# 1                                 Limited Commercial         811      676
# ...
